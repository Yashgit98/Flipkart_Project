# %%
import pandas as pd

# %%
df = pd.read_csv('Refrigerator_data.csv')

# %%
df
# Out:
#       Unnamed: 0                                               Name  Ratings  \
# 0              0  Voltas Beko by A Tata Product 360 L Frost Free...      4.0
# 1              1  Voltas Beko by A Tata Product 340 L Frost Free...      4.0
# 2              2  Whirlpool 192 L Direct Cool Single Door 3 Star...      4.1
# 3              3  SAMSUNG 183 L Direct Cool Single Door 4 Star R...      4.4
# 4              4  SAMSUNG 183 L Direct Cool Single Door 4 Star R...      4.4
# ...          ...                                                ...      ...
# 1108        1108  Voltas Beko by A Tata Product 432 L Frost Free...      3.8
# 1109        1109  Whirlpool 270 L Frost Free Triple Door Refrige...      4.3
# 1110        1110  LG 242 L Frost Free Double Door 3 Star Refrige...      4.4
# 1111        1111  SAMSUNG 183 L Direct Cool Single Door 5 Star R...      4.4
# 1112        1112  Whirlpool 235 L Frost Free Multi-Door Refriger...      3.3
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0
